# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
db.establishments.find_one({})
# Out:
# {'_id': ObjectId('67a40905c129f9cfdf7ef015'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query1 = {'scores.Hygiene': 20}
fields = {'_id':1, 
          'AddressLine1':1, 
          'AddressLine2':1, 
          'AddressLine3':1, 
          'AddressLine4':1, 
          'BusinessName':1, 
          'BusinessType':1, 
          'BusinessTypeID':1, 
          'PostCode':1, 
          'RatingDate':1, 
          'RatingKey':1, 
          'RatingValue':1, 
          'geocode':1, 
          'scores':1}

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query1))

# Display the first document in the results using pprint
pprint(establishments.find(query1, fields)[0])
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  '_id': ObjectId('67a40906c129f9cfdf7f0b47'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results = (establishments.find(query1, fields))
df = pd.json_normalize(results)

# Display the number of rows in the DataFrame
print(df.shape)

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# (41, 17)
#                         _id               BusinessName  \
# 0  67a40906c129f9cfdf7f0b47        The Chase Rest Home
# 1  67a40906c129f9cfdf7f0ec8                 Brenalwood
# 2  67a40906c129f9cfdf7f11d2              Melrose Hotel
# 3  67a40906c129f9cfdf7f13c0              Seaford Pizza
# 4  67a40906c129f9cfdf7f13cf              Golden Palace
# 5  67a40906c129f9cfdf7f1d6e           Ashby's Butchers
# 6  67a40906c129f9cfdf7f1f8f  South Sea Express Cuisine
# 7  67a40907c129f9cfdf7f34ba              Golden Palace
# 8  67a40907c129f9cfdf7f38fe             The Tulip Tree
# 9  67a40907c129f9cfdf7f4110                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3 AddressLine4  PostCode  RatingValue  \
# 0          Eastbourne  East Sussex               BN21 1BU            0
# 1  Walton-on-the-Naze        Essex               CO14 8HN            0
# 2      Clacton On Sea        Essex               CO15 6AD            0
# 3             Seaford  East Sussex               BN25 1PG            1
# 4             Seaford  East Sussex               BN25 1HP            1
# 5     Southend-On-Sea        Essex                SS1 2PP            0
# 6     Southend-on-sea        Essex                SS1 1BW            0
# 7            Rayleigh        Essex                SS6 9HN            0
# 8       Chiddingstone         KENT                TN8 7AH            1
# 9      81 Southernhay     Basildon        Essex  SS14 1EU            0
#
#       RatingKey           RatingDate  scores.Hygiene  scores.Structural  \
# 0  fhrs_0_en-gb  2021-09-23T00:00:00              20                 20
# 1  fhrs_0_en-gb  2022-06-22T00:00:00              20                 15
# 2  fhrs_0_en-gb  2021-08-13T00:00:00              20                 20
# 3  fhrs_1_en-gb  2021-12-23T00:00:00              20                 10
# 4  fhrs_1_en-gb  2021-10-07T00:00:00              20                 10
# 5  fhrs_0_en-gb  2022-07-21T00:00:00              20                 20
# 6  fhrs_0_en-gb  2022-08-03T00:00:00              20                 20
# 7  fhrs_0_en-gb  2022-03-23T00:00:00              20                 15
# 8  fhrs_1_en-gb  2022-03-04T00:00:00              20                  5
# 9  fhrs_0_en-gb  2021-07-26T00:00:00              20                 20
#
#    scores.ConfidenceInManagement  geocode.longitude  geocode.latitude
# 0                             20           0.276940         50.769705
# 1                             30           1.278721         51.857536
# 2                             20           1.159270         51.789429
# 3                             20           0.102020         50.770885
# 4                             20           0.101446         50.770724
# 5                             20           0.736349         51.541448
# 6                             20           0.712167         51.535007
# 7                             30           0.602364         51.591515
# 8                             20           0.146450         51.185947
# 9                             20           0.462307         51.570050

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query2 = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte': 4}}
fields = {'_id':1, 
          'AddressLine1':1, 
          'AddressLine2':1, 
          'AddressLine3':1, 
          'AddressLine4':1, 
          'BusinessName':1, 
          'BusinessType':1, 
          'BusinessTypeID':1, 
          'PostCode':1, 
          'RatingDate':1, 
          'RatingKey':1, 
          'RatingValue':1, 
          'geocode':1, 
          'scores':1}


# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query2))

# Display the first document in the results using pprint

pprint(establishments.find(query2, fields)[0])
# Out:
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  '_id': ObjectId('67a40906c129f9cfdf7f2562'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
results = (establishments.find(query2, fields))
df = pd.json_normalize(results)

# Display the number of rows in the DataFrame
print(df.shape)

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# (33, 17)
#                         _id                          BusinessName  \
# 0  67a40906c129f9cfdf7f2562                             Charlie's
# 1  67a40906c129f9cfdf7f2888               Mv City Cruises Erasmus
# 2  67a40907c129f9cfdf7f33d5             Benfleet Motor Yacht Club
# 3  67a40907c129f9cfdf7f41d5  Coombs Catering t/a The Lock and Key
# 4  67a40907c129f9cfdf7f41d6              Tilbury Seafarers Centre
# 5  67a40907c129f9cfdf7f48de                            Mv Valulla
# 6  67a40908c129f9cfdf7f69ec                         Tereza Joanne
# 7  67a40908c129f9cfdf7f6db3                      Brick Lane Brews
# 8  67a40908c129f9cfdf7f6dcd         The Nuance Group (UK) Limited
# 9  67a40908c129f9cfdf7f6dce                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3 AddressLine4  PostCode  \
# 0                           Sheppy Kent                                ME12
# 1      Cherry Garden Street Rotherhithe     Charlton                TN4 8HR
# 2                  South Benfleet Essex                             SS7 1NF
# 3                               Tilbury     Charlton               RM18 7EH
# 4                         Tilbury Essex                            RM18 7EH
# 5                                London                            RM15 5QY
# 6                                London                             E16 2NJ
# 7                                London                             E16 2PX
# 8  London City AirportRoyal DocksLondon                             E16 2PX
# 9                     Silvertown London                             E16 2PX
#
#    RatingValue     RatingKey           RatingDate  scores.Hygiene  \
# 0            4  fhrs_4_en-gb  2021-10-18T00:00:00               5
# 1            5  fhrs_5_en-gb  2021-05-14T00:00:00               0
# 2            4  fhrs_4_en-gb  2018-11-02T00:00:00               0
# 3            5  fhrs_5_en-gb  2020-12-04T00:00:00               0
# 4            5  fhrs_5_en-gb  2018-11-02T00:00:00               0
# 5            5  fhrs_5_en-gb  2016-08-23T00:00:00               0
# 6            5  fhrs_5_en-gb  2021-07-09T00:00:00               0
# 7            4  fhrs_4_en-gb  2019-01-18T00:00:00              10
# 8            5  fhrs_5_en-gb  2017-07-17T00:00:00               0
# 9            5  fhrs_5_en-gb  2017-07-17T00:00:00               0
#
#    scores.Structural  scores.ConfidenceInManagement  geocode.longitude  \
# 0                 10                              5           0.508551
# 1                  5                              0           0.249256
# 2                  0                             10           0.561954
# 3                  5                              0           0.346337
# 4                  0                              0           0.346325
# 5                  0                              0           0.287555
# 6                  5                              5           0.069286
# 7                  5                              5           0.048006
# 8                  0                              0           0.047966
# 9                  0                              0           0.047966
#
#    geocode.latitude
# 0         51.369321
# 1         51.123623
# 2         51.543831
# 3         51.464066
# 4         51.464078
# 5         51.504071
# 6         51.501121
# 7         51.503733
# 8         51.504112
# 9         51.504112

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query3 = {'RatingValue': 5, 
          'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
          'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search}}
fields = {'_id':1, 
          'AddressLine1':1, 
          'AddressLine2':1, 
          'AddressLine3':1, 
          'AddressLine4':1, 
          'BusinessName':1, 
          'BusinessType':1, 
          'BusinessTypeID':1, 
          'PostCode':1, 
          'RatingDate':1, 
          'RatingKey':1, 
          'RatingValue':1, 
          'geocode':1, 
          'scores':1}
sort = sort = [("scores.Hygiene", 1)]
limit = 5

# Print the results
print(establishments.count_documents(query3))

pprint(establishments.find(query3, fields).sort(sort).limit(limit)[0])
# Out:
# 87
# {'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-11-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  '_id': ObjectId('67a40908c129f9cfdf7f6379'),
#  'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# Convert result to Pandas DataFrame
results = (establishments.find(query3, fields))
df = pd.json_normalize(results)

# Display the number of rows in the DataFrame
print(df.shape)

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# (87, 17)
#                         _id                         BusinessName  \
# 0  67a40908c129f9cfdf7f6352   TIWA N TIWA African Restaurant Ltd
# 1  67a40908c129f9cfdf7f6379                              Iceland
# 2  67a40908c129f9cfdf7f6389  Howe and Co Fish and Chips - Van 17
# 3  67a40908c129f9cfdf7f63a6                            Volunteer
# 4  67a40908c129f9cfdf7f63be              Plumstead Manor Nursery
# 5  67a40908c129f9cfdf7f63c1                    Atlantic Fish Bar
# 6  67a40908c129f9cfdf7f63c3      Lumbini Grocery Ltd T/A Al-Iman
# 7  67a40908c129f9cfdf7f63e1                               Greggs
# 8  67a40908c129f9cfdf7f63e2                                Tesco
# 9  67a40908c129f9cfdf7f6409                Dosa & Sambal Express
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1  Retailers - supermarkets/hypermarkets            7840
# 2                         Mobile caterer            7846
# 3                      Pub/bar/nightclub            7843
# 4                        Caring Premises               5
# 5                 Takeaway/sandwich shop            7844
# 6                      Retailers - other            4613
# 7                 Takeaway/sandwich shop            7844
# 8  Retailers - supermarkets/hypermarkets            7840
# 9                Restaurant/Cafe/Canteen               1
#
#                                         AddressLine1 AddressLine2  \
# 0                          152 Plumstead High Street
# 1                    144 - 146 Plumstead High Street
# 2  Restaurant And Premises 107A Plumstead High St...
# 3                    130 - 132 Plumstead High Street
# 4               Plumstead Manor School Old Mill Road
# 5                                   35 Lakedale Road
# 6                                   17 Lakedale Road
# 7                                    6 Lakedale Road
# 8                                   18 Lakedale Road
# 9                         107A Plumstead High Street
#
#   AddressLine3 AddressLine4  PostCode  RatingValue     RatingKey  \
# 0    Plumstead    Greenwich  SE18 1JQ            5  fhrs_5_en-gb
# 1    Plumstead    Greenwich  SE18 1JQ            5  fhrs_5_en-gb
# 2    Plumstead    Greenwich  SE18 1SE            5  fhrs_5_en-gb
# 3    Plumstead    Greenwich  SE18 1JQ            5  fhrs_5_en-gb
# 4    Plumstead    Greenwich  SE18 1QG            5  fhrs_5_en-gb
# 5    Plumstead    Greenwich  SE18 1PR            5  fhrs_5_en-gb
# 6    Plumstead    Greenwich  SE18 1PP            5  fhrs_5_en-gb
# 7    Plumstead    Greenwich  SE18 1PP            5  fhrs_5_en-gb
# 8    Plumstead    Greenwich  SE18 1PP            5  fhrs_5_en-gb
# 9    Plumstead    Greenwich                      5  fhrs_5_en-gb
#
#             RatingDate  scores.Hygiene  scores.Structural  \
# 0  2020-10-24T00:00:00               5                  5
# 1  2019-11-13T00:00:00               0                  5
# 2  2021-11-11T00:00:00               0                  0
# 3  2019-08-05T00:00:00               0                  0
# 4  2021-06-16T00:00:00               0                  0
# 5  2021-06-16T00:00:00               0                  0
# 6  2020-10-20T00:00:00               0                  5
# 7  2021-06-23T00:00:00               0                  0
# 8  2020-10-20T00:00:00               0                  5
# 9  2020-07-09T00:00:00               0                  0
#
#    scores.ConfidenceInManagement  geocode.longitude  geocode.latitude
# 0                              5           0.092743         51.487035
# 1                              5           0.092420         51.487148
# 2                              0           0.092537         51.487534
# 3                              0           0.092080         51.487344
# 4                              5           0.085994         51.481518
# 5                              5           0.091216         51.486730
# 6                              0           0.091626         51.487163
# 7                              0           0.091282         51.487141
# 8                              0           0.091282         51.487141
# 9                              5           0.091566         51.487758

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match = {'$match': {'scores.Hygiene': 0}}

# 2. Groups the matches by Local Authority
group = {'$group': {'_id': {'LocalAuthorityName': '$LocalAuthorityName'},
                    'num_restaurants': {'$sum': 1}}}

# 3. Sorts the matches from highest to lowest
sort = {'$sort': {'num_restaurants': -1}} 

# Print the number of documents in the result
pipeline = [match, group, sort]
results = list(establishments.aggregate(pipeline))

# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': {'LocalAuthorityName': 'Thanet'}, 'num_restaurants': 1130},
#  {'_id': {'LocalAuthorityName': 'Greenwich'}, 'num_restaurants': 882},
#  {'_id': {'LocalAuthorityName': 'Maidstone'}, 'num_restaurants': 713},
#  {'_id': {'LocalAuthorityName': 'Newham'}, 'num_restaurants': 711},
#  {'_id': {'LocalAuthorityName': 'Swale'}, 'num_restaurants': 686},
#  {'_id': {'LocalAuthorityName': 'Chelmsford'}, 'num_restaurants': 680},
#  {'_id': {'LocalAuthorityName': 'Medway'}, 'num_restaurants': 672},
#  {'_id': {'LocalAuthorityName': 'Bexley'}, 'num_restaurants': 607},
#  {'_id': {'LocalAuthorityName': 'Southend-On-Sea'}, 'num_restaurants': 586},
#  {'_id': {'LocalAuthorityName': 'Tendring'}, 'num_restaurants': 542}]

# %%
# Convert the result to a Pandas DataFrame
df = pd.json_normalize(results)

# Display the number of rows in the DataFrame
print(df.shape)

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# (55, 2)
#    num_restaurants _id.LocalAuthorityName
# 0             1130                 Thanet
# 1              882              Greenwich
# 2              713              Maidstone
# 3              711                 Newham
# 4              686                  Swale
# 5              680             Chelmsford
# 6              672                 Medway
# 7              607                 Bexley
# 8              586        Southend-On-Sea
# 9              542               Tendring
